# %% [markdown]
# ## 🧹 Limpieza de datos 🧹

# %% [markdown]
# ##**🧹 Importamos las librerias que vamos a utilizar**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **🧹Abrimos el dataset con los que vamos a trabajar.**
# Cuando hablamos de **Dataset**, nos referimos a un conjunto de datos (se pueden encontrar en diferentes formatos: CSV, PARQUET, JSON, etc...)
# ##En nuestro caso, dicho data set se encuentran en formato CSV.
# CSV es un archivo de texto que contiene datos separados por coma y nos permite guardar los datos en un formato de tabla estructurada.
# Cada regitro está separado por un salto de línea.
#
# #Ejemplo:
# ![csvEjemplo](https://3.bp.blogspot.com/-53Ahq0v3ehw/Xe_fwe_CDaI/AAAAAAAAAhk/J2y4eQinue8likCs8W7t-IXw_n5by3vuQCLcBGAsYHQ/w1200-h630-p-k-no-nu/archivo%2Bcsv.PNG)

# %% [markdown]
# Nuestro conjunto de datos lo vamos a abrir desde GIT HUB: [MESSI.CSV](https://github.com/cristiandarioortegayubro/base/tree/main/dataset)
# ~~~markdown
# https://github.com/cristiandarioortegayubro/base/tree/main/dataset
# ~~~

# %%
dfMessi= pd.read_csv("https://raw.githubusercontent.com/cristiandarioortegayubro/base/main/dataset/messiSucio.csv")

# %% [markdown]
# 🧹 Para ver todo el contenido de una columna

# %%
dfMessi
# Out:
#             Tournament     Matchday      Date Venue          Club  \
# 0              LaLiga            34    5/1/05  Home  FC Barcelona
# 1    Champions League   Group Stage   11/2/05  Home  FC Barcelona
# 2              LaLiga            13  11/27/05  Home  FC Barcelona
# 3              LaLiga            19   1/15/06  Home  FC Barcelona
# 4              LaLiga            20   1/22/06  Home  FC Barcelona
# ..                 ...          ...       ...   ...           ...
# 743                NaN          NaN       NaN   NaN           NaN
# 744                NaN          NaN       NaN   NaN           NaN
# 745                NaN          NaN       NaN   NaN           NaN
# 746                NaN          NaN       NaN   NaN           NaN
# 747                NaN          NaN       NaN   NaN           NaN
#
#                  Opponent Result Position Minute When Scored  \
# 0       Albacete Balompié    2:0       CF  90'+1         2:0
# ...

# %% [markdown]
# 🧹 Dimensiones de nuestro archivo

# %%
dfMessi.shape
# Out:
# (748, 13)

# %%
dfMessi.shape[0]
# Out:
# 748

# %%
dfMessi.shape[1]
# Out:
# 13

# %% [markdown]
# 🧹Vemos las primeras 5 filas

# %%
dfMessi.head()
# Out:
#           Tournament     Matchday      Date Venue          Club  \
# 0            LaLiga            34    5/1/05  Home  FC Barcelona
# 1  Champions League   Group Stage   11/2/05  Home  FC Barcelona
# 2            LaLiga            13  11/27/05  Home  FC Barcelona
# 3            LaLiga            19   1/15/06  Home  FC Barcelona
# 4            LaLiga            20   1/22/06  Home  FC Barcelona
#
#                Opponent Result Position Minute When Scored         Goal Type  \
# 0     Albacete Balompié    2:0       CF  90'+1         2:0  Left-footed shot
# 1  Panathinaikos Athens    5:0       RW    34'         3:0  Left-footed shot
# 2      Racing Santander    4:1       RW    51'         2:0  Left-footed shot
# 3       Athletic Bilbao    2:1       RW    50'         2:1  Left-footed shot
# 4      Deportivo Alavés    2:0       CF    82'         2:0  Left-footed shot
#
#               Assist            Pareja
# 0  Ronaldinho Gaúcho  Antonela Rocuzzo
# ...

# %% [markdown]
# 🧹 Podemos cambiar los nombres de las columnas a español para visualizar mejor los datos

# %%
dfMessi.columns
# Out:
# Index(['Tournament', 'Matchday', 'Date', 'Venue', 'Club', 'Opponent', 'Result',
#        'Position', 'Minute', 'When Scored', 'Goal Type', 'Assist', 'Pareja'],
#       dtype='object')

# %%
nombresEspañol = {
                'Tournament':'Torneo',
                'Matchday':'Jornada',
               'Date':'Fecha',
               'Venue':'Evento', 
               'Opponent':'Oponente', 
                'Result':'Resultado',
                'Position':'Posición',
                'Minute':'Minuto',
                'When Scored':'Momento_del_gol',
                'Goal Type':'Tipo_de_gol',
                'Assist':'Asistente'}
             
dfMessi.rename(columns=nombresEspañol, inplace=True)

# %%
dfMessi.head()
# Out:
#               Torneo      Jornada     Fecha Evento          Club  \
# 0            LaLiga            34    5/1/05   Home  FC Barcelona
# 1  Champions League   Group Stage   11/2/05   Home  FC Barcelona
# 2            LaLiga            13  11/27/05   Home  FC Barcelona
# 3            LaLiga            19   1/15/06   Home  FC Barcelona
# 4            LaLiga            20   1/22/06   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento_del_gol  \
# 0     Albacete Balompié       2:0       CF  90'+1             2:0
# 1  Panathinaikos Athens       5:0       RW    34'             3:0
# 2      Racing Santander       4:1       RW    51'             2:0
# 3       Athletic Bilbao       2:1       RW    50'             2:1
# 4      Deportivo Alavés       2:0       CF    82'             2:0
#
#         Tipo_de_gol          Asistente            Pareja
# 0  Left-footed shot  Ronaldinho Gaúcho  Antonela Rocuzzo
# 1  Left-footed shot     Not Applicable  Antonela Rocuzzo
# ...

# %% [markdown]
# 🧹 Visualizamos tipo de datos y cantidad de elementos no nulos por columna

# %%
dfMessi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Torneo           712 non-null    object
#  1   Jornada          712 non-null    object
#  2   Fecha            712 non-null    object
#  3   Evento           712 non-null    object
#  4   Club             712 non-null    object
#  5   Oponente         712 non-null    object
#  6   Resultado        712 non-null    object
#  7   Posición         712 non-null    object
#  8   Minuto           712 non-null    object
#  9   Momento_del_gol  712 non-null    object
#  10  Tipo_de_gol      712 non-null    object
#  11  Asistente        712 non-null    object
#  12  Pareja           712 non-null    object
# dtypes: object(13)
# memory usage: 76.1+ KB

# %% [markdown]
# 🧹 Si hay datos que no corresponden con el contenido del dato, debemos cambiarlos.
#
# > **Podemos comenzar por los que no contienen diferentes tipos de datos como números y fechas, o números y strings **

# %%
dfMessi.dtypes
# Out:
# Torneo             object
# Jornada            object
# Fecha              object
# Evento             object
# Club               object
# Oponente           object
# Resultado          object
# Posición           object
# Minuto             object
# Momento_del_gol    object
# Tipo_de_gol        object
# Asistente          object
# Pareja             object
# dtype: object

# %%
dfMessi.head()
# Out:
#               Torneo      Jornada     Fecha Evento          Club  \
# 0            LaLiga            34    5/1/05   Home  FC Barcelona
# 1  Champions League   Group Stage   11/2/05   Home  FC Barcelona
# 2            LaLiga            13  11/27/05   Home  FC Barcelona
# 3            LaLiga            19   1/15/06   Home  FC Barcelona
# 4            LaLiga            20   1/22/06   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento_del_gol  \
# 0     Albacete Balompié       2:0       CF  90'+1             2:0
# 1  Panathinaikos Athens       5:0       RW    34'             3:0
# 2      Racing Santander       4:1       RW    51'             2:0
# 3       Athletic Bilbao       2:1       RW    50'             2:1
# 4      Deportivo Alavés       2:0       CF    82'             2:0
#
#         Tipo_de_gol          Asistente            Pareja
# 0  Left-footed shot  Ronaldinho Gaúcho  Antonela Rocuzzo
# 1  Left-footed shot     Not Applicable  Antonela Rocuzzo
# ...

# %%
dfMessi["Minuto"].unique()
# Out:
# array(["90'+1", "34'", "51'", "50'", "82'", "75'", "83'", "42'", "84'",
#        "59'", "36'", "89'", "80'", "11'", "28'", "86'", "45'", "29'",
#        "39'", "43'", "57'", "72'", "79'", "5'", "10'", "66'", "19'",
#        "41'", "81'", "58'", "18'", "44'", "70'", "85'", "90'", "87'",
#        "90'+2", "8'", "4'", "61'", "49'", "78'", "21'", "76'", "65'",
#        "30'", "31'", "40'", "26'", "9'", "38'", "23'", "35'", "55'",
#        "68'", "15'", "90'+3", "63'", "25'", "64'", "110'", "54'", "7'",
#        "56'", "13'", "67'", "37'", "88'", "32'", "16'", "74'", "3'",
#        "22'", "12'", "20'", "46'", "73'", "33'", "77'", "52'", "53'",
#        "69'", "24'", "45'+2", "17'", "71'", "27'", "60'", "48'", "6'",
#        "62'", "45'+1", "90'+4", "47'", "14'", "45'+4", nan], dtype=object)

# %%
dfMessi["Momento_del_gol"]. unique()
# Out:
# array(['2:0', '3:0', '2:1', '0:2', '0:3', '1:0', '5:1', '1:2', '1:1',
#        '3:1', '2:2', '3:3', '0:4', '0:1', '0:5', '2:3', '1:5', '1:6',
#        '1:3', '4:1', '2:5', '5:2', '4:0', '1:4', '0:7', '3:2', '5:0',
#        '8:0', '4:2', '7:0', '2:4', '3:5', '6:0', '3:4', '0:6', '6:1',
#        '6:2', '4:3', nan], dtype=object)

# %%
dfMessi["Fecha"]. unique()
# Out:
# array(['5/1/05', '11/2/05', '11/27/05', '1/15/06', '1/22/06', '1/29/06',
#        '2/1/06', '2/18/06', '8/28/06', '9/9/06', '9/27/06', '10/15/06',
#        '3/10/07', '3/17/07', '3/31/07', '4/18/07', '5/20/07', '6/9/07',
#        '6/17/07', '9/19/07', '9/22/07', '9/26/07', '9/29/07', '10/2/07',
#        '10/7/07', '10/28/07', '11/7/07', '11/24/07', '11/27/07',
#        '2/20/08', '2/24/08', '5/4/08', '9/13/08', '9/21/08', '9/27/08',
#        '10/1/08', '10/4/08', '10/22/08', '11/1/08', '11/4/08', '11/12/08',
#        '11/16/08', '11/26/08', '11/29/08', '12/13/08', '1/6/09',
#        '1/11/09', '1/17/09', '1/24/09', '2/1/09', '3/1/09', '3/4/09',
#        '3/7/09', '3/11/09', '3/22/09', '4/8/09', '4/18/09', '4/25/09',
#        '5/2/09', '5/13/09', '5/27/09', '8/23/09', '9/12/09', '9/19/09',
#        '9/22/09', '9/29/09', '10/25/09', '11/7/09', '11/10/09', '12/5/09',
#        '12/9/09', '12/16/09', '12/19/09', '1/10/10', '1/16/10', '1/23/10',
# ...

# %% [markdown]
# > Convertimos los tipos de datos

# %%
dfMessi.head()
# Out:
#               Torneo      Jornada     Fecha Evento          Club  \
# 0            LaLiga            34    5/1/05   Home  FC Barcelona
# 1  Champions League   Group Stage   11/2/05   Home  FC Barcelona
# 2            LaLiga            13  11/27/05   Home  FC Barcelona
# 3            LaLiga            19   1/15/06   Home  FC Barcelona
# 4            LaLiga            20   1/22/06   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento_del_gol  \
# 0     Albacete Balompié       2:0       CF  90'+1             2:0
# 1  Panathinaikos Athens       5:0       RW    34'             3:0
# 2      Racing Santander       4:1       RW    51'             2:0
# 3       Athletic Bilbao       2:1       RW    50'             2:1
# 4      Deportivo Alavés       2:0       CF    82'             2:0
#
#         Tipo_de_gol          Asistente            Pareja
# 0  Left-footed shot  Ronaldinho Gaúcho  Antonela Rocuzzo
# 1  Left-footed shot     Not Applicable  Antonela Rocuzzo
# ...

# %%
dfMessi["Torneo"] = dfMessi["Torneo"].astype("string")
dfMessi["Jornada"] = dfMessi["Jornada"].astype("string")
dfMessi["Fecha"] = pd.to_datetime(dfMessi["Fecha"])
dfMessi["Evento"] = dfMessi["Evento"].astype("string")
dfMessi["Club"] = dfMessi["Club"].astype("string")
dfMessi["Oponente"] = dfMessi["Oponente"].astype("string")
dfMessi["Resultado"] = dfMessi["Resultado"].astype("string")
dfMessi["Posición"] = dfMessi["Posición"].astype("string")
dfMessi["Tipo_de_gol"] = dfMessi["Tipo_de_gol"].astype("string")
dfMessi["Asistente"] = dfMessi["Asistente"].astype("string")
dfMessi["Pareja"] = dfMessi["Pareja"].astype("string")
dfMessi["Minuto"] = dfMessi["Minuto"].astype("string")
dfMessi["Momento_del_gol"] = dfMessi["Momento_del_gol"].astype("string")

# %%
dfMessi.dtypes
# Out:
# Torneo                     string
# Jornada                    string
# Fecha              datetime64[ns]
# Evento                     string
# Club                       string
# Oponente                   string
# Resultado                  string
# Posición                   string
# Minuto                     string
# Momento_del_gol            string
# Tipo_de_gol                string
# Asistente                  string
# Pareja                     string
# dtype: object

# %% [markdown]
# 🧹 El método **describe()** devuelve la descripción de los datos en el DataFrame.
#
# Si el DataFrame contiene datos numéricos, la descripción contiene esta información para cada columna:
#
# >**count**: el número de valores no vacíos.
#
# >**unique**: valor único.
#
# >**top**: El elemento que más se repite.
#
# >**freq**: La cantidad de veces que se repite dicho elemento

# %%
dfMessi.describe()
# Out:
# <ipython-input-48-89692bf37c3b>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dfMessi.describe()
#          Torneo      Jornada                Fecha Evento          Club  \
# count       712          712                  712    712           712
# unique        8           46                  445      2             2
# top     LaLiga   Group Stage  2022-08-06 00:00:00   Home  FC Barcelona
# freq        474           79                    6    420           672
# first       NaN          NaN  2005-05-01 00:00:00    NaN           NaN
# last        NaN          NaN  2022-10-01 00:00:00    NaN           NaN
#
#           Oponente Resultado Posición Minuto Momento_del_gol  \
# count          712       712      712    712             712
# ...

# %% [markdown]
# Divisamos porcentajes de nulos por cada columna

# %%
dfMessi.isnull().sum()
# Out:
# Torneo             36
# Jornada            36
# Fecha              36
# Evento             36
# Club               36
# Oponente           36
# Resultado          36
# Posición           36
# Minuto             36
# Momento_del_gol    36
# Tipo_de_gol        36
# Asistente          36
# Pareja             36
# dtype: int64

# %%
dfMessi.isnull().sum() / dfMessi.shape[0] * 100
# Out:
# Torneo             4.812834
# Jornada            4.812834
# Fecha              4.812834
# Evento             4.812834
# Club               4.812834
# Oponente           4.812834
# Resultado          4.812834
# Posición           4.812834
# Minuto             4.812834
# Momento_del_gol    4.812834
# Tipo_de_gol        4.812834
# Asistente          4.812834
# Pareja             4.812834
# dtype: float64

# %%
dfMessi.isnull().sum()*100/dfMessi.shape[0]
# Out:
# Torneo             4.812834
# Jornada            4.812834
# Fecha              4.812834
# Evento             4.812834
# Club               4.812834
# Oponente           4.812834
# Resultado          4.812834
# Posición           4.812834
# Minuto             4.812834
# Momento_del_gol    4.812834
# Tipo_de_gol        4.812834
# Asistente          4.812834
# Pareja             4.812834
# dtype: float64

# %%
dfMessi.isnull().sum() / dfMessi.shape[1] * 100
# Out:
# Torneo             276.923077
# Jornada            276.923077
# Fecha              276.923077
# Evento             276.923077
# Club               276.923077
# Oponente           276.923077
# Resultado          276.923077
# Posición           276.923077
# Minuto             276.923077
# Momento_del_gol    276.923077
# Tipo_de_gol        276.923077
# Asistente          276.923077
# Pareja             276.923077
# dtype: float64

# %% [markdown]
# 🧹 Eliminamos las filas que tienen todos nulos

# %%
dfMessi.dropna(how="all", axis=0, inplace=True)

# %%
dfMessi.isnull().sum()
# Out:
# Torneo             0
# Jornada            0
# Fecha              0
# Evento             0
# Club               0
# Oponente           0
# Resultado          0
# Posición           0
# Minuto             0
# Momento_del_gol    0
# Tipo_de_gol        0
# Asistente          0
# Pareja             0
# dtype: int64

# %%
dfMessi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 711
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Torneo           712 non-null    string
#  1   Jornada          712 non-null    string
#  2   Fecha            712 non-null    datetime64[ns]
#  3   Evento           712 non-null    string
#  4   Club             712 non-null    string
#  5   Oponente         712 non-null    string
#  6   Resultado        712 non-null    string
#  7   Posición         712 non-null    string
#  8   Minuto           712 non-null    string
#  9   Momento_del_gol  712 non-null    string
#  10  Tipo_de_gol      712 non-null    string
#  11  Asistente        712 non-null    string
#  12  Pareja           712 non-null    string
# dtypes: datetime64[ns](1), string(12)
# memory usage: 77.9 KB

# %% [markdown]
# 🧹 Eliminamos las filas que tienen un porcentaje de NaN mayor al 80%

# %%
dfMessi.dropna(axis=0, thresh=int(0.8*dfMessi.shape[1]))
# Out:
#                 Torneo      Jornada      Fecha Evento                 Club  \
# 0              LaLiga            34 2005-05-01   Home         FC Barcelona
# 1    Champions League   Group Stage 2005-11-02   Home         FC Barcelona
# 2              LaLiga            13 2005-11-27   Home         FC Barcelona
# 3              LaLiga            19 2006-01-15   Home         FC Barcelona
# 4              LaLiga            20 2006-01-22   Home         FC Barcelona
# ..                 ...          ...        ...    ...                  ...
# 707           Ligue 1             1 2022-08-06   Away  Paris Saint-Germain
# 708           Ligue 1             3 2022-08-21   Away  Paris Saint-Germain
# 709  Champions League   Group Stage 2022-09-14   Away  Paris Saint-Germain
# 710           Ligue 1             8 2022-09-18   Away  Paris Saint-Germain
# 711           Ligue 1             9 2022-10-01   Home  Paris Saint-Germain
#
# ...

# %%
dfMessi.shape
# Out:
# (712, 13)

# %%
dfMessi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 711
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Torneo           712 non-null    string
#  1   Jornada          712 non-null    string
#  2   Fecha            712 non-null    datetime64[ns]
#  3   Evento           712 non-null    string
#  4   Club             712 non-null    string
#  5   Oponente         712 non-null    string
#  6   Resultado        712 non-null    string
#  7   Posición         712 non-null    string
#  8   Minuto           712 non-null    string
#  9   Momento_del_gol  712 non-null    string
#  10  Tipo_de_gol      712 non-null    string
#  11  Asistente        712 non-null    string
#  12  Pareja           712 non-null    string
# dtypes: datetime64[ns](1), string(12)
# memory usage: 77.9 KB

# %% [markdown]
# 🧹 Eliminamos las columnas completas que no nos van a servir para nuestro análisis o que no tienen información relevante

# %%
#por ejemplo, pareja 

dfMessi.drop("Pareja", axis=1, inplace=True)

# %%
dfMessi.shape
# Out:
# (712, 12)

# %% [markdown]
# 🧹 Eliminamos columnas duplicadas.
# > Si este es el caso, se quedará con una de las dos filas

# %%
dfMessi.drop_duplicates(keep='first', inplace=True)

# %%
dfMessi
# Out:
#                 Torneo      Jornada      Fecha Evento                 Club  \
# 0              LaLiga            34 2005-05-01   Home         FC Barcelona
# 1    Champions League   Group Stage 2005-11-02   Home         FC Barcelona
# 2              LaLiga            13 2005-11-27   Home         FC Barcelona
# 3              LaLiga            19 2006-01-15   Home         FC Barcelona
# 4              LaLiga            20 2006-01-22   Home         FC Barcelona
# ..                 ...          ...        ...    ...                  ...
# 685           Ligue 1             1 2022-08-06   Away  Paris Saint-Germain
# 686           Ligue 1             3 2022-08-21   Away  Paris Saint-Germain
# 687  Champions League   Group Stage 2022-09-14   Away  Paris Saint-Germain
# 688           Ligue 1             8 2022-09-18   Away  Paris Saint-Germain
# 689           Ligue 1             9 2022-10-01   Home  Paris Saint-Germain
#
# ...

# %%
dfMessi.shape
# Out:
# (690, 12)

# %% [markdown]
# 🧹 Separamos datos que nos resulten útiles durante el análisis.
# Por ejemplo: Podemos crear una columna solo con el año.

# %%
dfMessi["Año"] = dfMessi["Fecha"].dt.year

# %%
dfMessi.shape
# Out:
# (690, 13)

# %% [markdown]
# 🧹 Separamos la columna resultado: Resultado_oponente y Resultado_equipo

# %%
dfMessi.Resultado.unique()
# Out:
# <StringArray>
# ['2:0', '5:0', '4:1', '2:1', '0:3', '5:1', '2:3', '3:0', '1:1', '3:1', '3:3',
#  '0:4', '5:2', '0:6', '2:2', '1:5', '1:4', '0:2', '6:0', '1:6', '1:2', '6:1',
#  '0:5', '1:0', '2:5', '1:3', '4:3', '4:0', '0:1', '2:6', '4:2', '2:4', '0:8',
#  '3:2', '8:0', '7:1', '5:3', '0:7', '4:5', '7:0', '3:4', '5:4', '6:2', '8:2',
#  '4:4', '1:7']
# Length: 46, dtype: string

# %%
'2:0'.split(":")
# Out:
# ['2', '0']

# %%
def separarColumnas(row):
  resultado = row['Resultado']
  evento = row['Evento']
  resultadoSeparado = resultado.split(":")

  if evento == "Home":
    return resultadoSeparado[0], resultadoSeparado[1]
  elif evento == "Away":
   return resultadoSeparado[1], resultadoSeparado[0]

# %%
dfMessi[["Resultado Equipo", "Resultado Oponente"]] = dfMessi.apply(lambda x: separarColumnas(x), axis=1, result_type="expand")

# %%
dfMessi
# Out:
#                 Torneo      Jornada      Fecha Evento                 Club  \
# 0              LaLiga            34 2005-05-01   Home         FC Barcelona
# 1    Champions League   Group Stage 2005-11-02   Home         FC Barcelona
# 2              LaLiga            13 2005-11-27   Home         FC Barcelona
# 3              LaLiga            19 2006-01-15   Home         FC Barcelona
# 4              LaLiga            20 2006-01-22   Home         FC Barcelona
# ..                 ...          ...        ...    ...                  ...
# 685           Ligue 1             1 2022-08-06   Away  Paris Saint-Germain
# 686           Ligue 1             3 2022-08-21   Away  Paris Saint-Germain
# 687  Champions League   Group Stage 2022-09-14   Away  Paris Saint-Germain
# 688           Ligue 1             8 2022-09-18   Away  Paris Saint-Germain
# 689           Ligue 1             9 2022-10-01   Home  Paris Saint-Germain
#
# ...

# %% [markdown]
# 🧹 Vamos a convertir en tipo númerico el minuto del gol

# %%
dfMessi[["Minuto"]]
# Out:
#     Minuto
# 0    90'+1
# 1      34'
# 2      51'
# 3      50'
# 4      82'
# ..     ...
# 685    86'
# 686    27'
# 687    37'
# 688     5'
# 689    28'
#
# [690 rows x 1 columns]

# %%
def convertirNumeros(x):
  if type(x) == str:
    string = x.split("+")
    string = [int(s.strip("'")) for s in string]
    return sum(string)

# %%
dfMessi["Minuto Numerico"] = dfMessi["Minuto"].apply(lambda x: convertirNumeros(x))

# %% [markdown]
# # 🔎 **Análisis de datos**

# %% [markdown]
# 🔎 ¿Mete más goles en primer o segundo tiempo?

# %%
dfMessi.head()
# Out:
#               Torneo      Jornada      Fecha Evento          Club  \
# 0            LaLiga            34 2005-05-01   Home  FC Barcelona
# 1  Champions League   Group Stage 2005-11-02   Home  FC Barcelona
# 2            LaLiga            13 2005-11-27   Home  FC Barcelona
# 3            LaLiga            19 2006-01-15   Home  FC Barcelona
# 4            LaLiga            20 2006-01-22   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento_del_gol  \
# 0     Albacete Balompié       2:0       CF  90'+1             2:0
# 1  Panathinaikos Athens       5:0       RW    34'             3:0
# 2      Racing Santander       4:1       RW    51'             2:0
# 3       Athletic Bilbao       2:1       RW    50'             2:1
# 4      Deportivo Alavés       2:0       CF    82'             2:0
#
#         Tipo_de_gol          Asistente   Año Resultado Equipo  \
# 0  Left-footed shot  Ronaldinho Gaúcho  2005                2
# ...

# %%
def enQueTiempo(row):
  if type(row) == str:
    string = row.split("+")
    string = [int(s.replace("'", "")) for s in string]
    if len(string) == 2:
      return "Primer tiempo extra" if string[0] == 45 else "Segundo tiempo extra"
    else:
      if string[0] <= 45:
        return "Primer tiempo"
      else:
        return "Segundo tiempo"

# %%
dfMessi["Momento_del_gol"].unique()
# Out:
# <StringArray>
# ['2:0', '3:0', '2:1', '0:2', '0:3', '1:0', '5:1', '1:2', '1:1', '3:1', '2:2',
#  '3:3', '0:4', '0:1', '0:5', '2:3', '1:5', '1:6', '1:3', '4:1', '2:5', '5:2',
#  '4:0', '1:4', '0:7', '3:2', '5:0', '8:0', '4:2', '7:0', '2:4', '3:5', '6:0',
#  '3:4', '0:6', '6:1', '6:2', '4:3']
# Length: 38, dtype: string

# %%
dfMessi.Minuto.unique()
# Out:
# <StringArray>
# ["90'+1",   "34'",   "51'",   "50'",   "82'",   "75'",   "83'",   "42'",
#    "84'",   "59'",   "36'",   "89'",   "80'",   "11'",   "28'",   "86'",
#    "45'",   "29'",   "39'",   "43'",   "57'",   "72'",   "79'",    "5'",
#    "10'",   "66'",   "19'",   "41'",   "81'",   "58'",   "18'",   "44'",
#    "70'",   "85'",   "90'",   "87'", "90'+2",    "8'",    "4'",   "61'",
#    "49'",   "78'",   "21'",   "76'",   "65'",   "30'",   "31'",   "40'",
#    "26'",    "9'",   "38'",   "23'",   "35'",   "55'",   "68'",   "15'",
#  "90'+3",   "63'",   "25'",   "64'",  "110'",   "54'",    "7'",   "56'",
#    "13'",   "67'",   "37'",   "88'",   "32'",   "16'",   "74'",    "3'",
#    "22'",   "12'",   "20'",   "46'",   "73'",   "33'",   "77'",   "52'",
#    "53'",   "69'",   "24'", "45'+2",   "17'",   "71'",   "27'",   "60'",
#    "48'",    "6'",   "62'", "45'+1", "90'+4",   "47'",   "14'", "45'+4"]
# Length: 96, dtype: string

# %%
dfMessi['Momento_del_gol'] = dfMessi['Minuto'].apply(lambda x: enQueTiempo(x))

# %%
golesPrimerTiempo= dfMessi[dfMessi.Momento_del_gol.isin(['Primer tiempo'])].count()[0] 
golesSegundoTiempo= dfMessi[dfMessi.Momento_del_gol.isin(['Segundo tiempo'])].count()[0]
golesPrimerTiempoExtra=dfMessi[dfMessi.Momento_del_gol.isin(["Primer tiempo extra"])].count()[0]
golesSegundoTiempoExtra=dfMessi[dfMessi.Momento_del_gol.isin(["Segundo tiempo extra"])].count()[0]

print(golesPrimerTiempo)
print(golesSegundoTiempo)
print(golesPrimerTiempoExtra)
print(golesSegundoTiempoExtra)
# Out:
# 298
# 360
# 6
# 26

# %%
dfMessi.shape[0]
# Out:
# 690

# %%
golesPrimerTiempo= dfMessi[dfMessi.Momento_del_gol.isin(['Primer tiempo'])].count()[0] 
golesSegundoTiempo= dfMessi[dfMessi.Momento_del_gol.isin(['Segundo tiempo'])].count()[0]
golesPrimerTiempoExtra=dfMessi[dfMessi.Momento_del_gol.isin(["Primer tiempo extra"])].count()[0]
golesSegundoTiempoExtra=dfMessi[dfMessi.Momento_del_gol.isin(["Segundo tiempo extra"])].count()[0]


print(f"El procentaje de goles en el primer tiempo es {(golesPrimerTiempo/ dfMessi.shape[0] * 100)} %")
print(f"El procentaje de goles en el primer tiempo extra es {(golesPrimerTiempoExtra/ dfMessi.shape[0] * 100)} %")
print(f"El procentaje de goles en el segundo tiempo es {(golesSegundoTiempo / dfMessi.shape[0] * 100 )} %")
print(f"El procentaje de goles en el segundo tiempo extra es {(golesSegundoTiempoExtra / dfMessi.shape[0] * 100)} %")
# Out:
# El procentaje de goles en el primer tiempo es 43.188405797101446 %
# El procentaje de goles en el primer tiempo extra es 0.8695652173913043 %
# El procentaje de goles en el segundo tiempo es 52.17391304347826 %
# El procentaje de goles en el segundo tiempo extra es 3.768115942028986 %

# %% [markdown]
# **🔎 ¿Cuantos goles hizo Messi por partido? (Debemos sacar el promedio)**
#
# > En está parte debemos agrupar los registros de goles por partido. Pueden pasar que dos goles o más se realicen en un mismo partido

# %%
golesPorPartido= dfMessi.groupby(pd.Grouper(key="Fecha")).count().mean()
golesPorPartidoPromedio = golesPorPartido.mean()
print(f"El promedio de goles por partido es de {golesPorPartidoPromedio}")
# Out:
# El promedio de goles por partido es de 1.5505617977528092

# %% [markdown]
# 🔎 Total de goles por año

# %%
golesPorAño = dfMessi["Año"].value_counts().sort_index()
print(f"El total de goles por año es {golesPorAño}")
# Out:
# El total de goles por año es 2005     3
# 2006    10
# 2007    25
# 2008    20
# 2009    38
# 2010    58
# 2011    55
# 2012    79
# 2013    39
# 2014    50
# 2015    48
# 2016    51
# 2017    50
# 2018    47
# 2019    45
# 2020    26
# 2021    34
# 2022    12
# Name: Año, dtype: int64

# %% [markdown]
# 🔎 Promedio de de goles por tipo de movimiento

# %%
partidosJugados=dfMessi['Fecha'].unique() 
partidosJugados.shape[0]
# Out:
# 445

# %%
tipodemov = dfMessi['Tipo_de_gol'].value_counts()
partidosJugados=dfMessi['Fecha'].unique()
tipodemov.apply(lambda x : x/partidosJugados.shape[0])
# Out:
# Left-footed shot          0.955056
# Penalty                   0.188764
# Right-footed shot         0.186517
# Direct free kick          0.114607
# Header                    0.053933
# Tap-in                    0.022472
# Solo run                  0.008989
# Penalty rebound           0.006742
# Deflected shot on goal    0.004494
# Not Applicable            0.002247
# Counter attack goal       0.002247
# Chest                     0.002247
# Long distance kick        0.002247
# Name: Tipo_de_gol, dtype: float64
